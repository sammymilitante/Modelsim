# %% [markdown]
# <a href="https://colab.research.google.com/github/sammymilitante/Modelsim/blob/master/Reading_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Reading an image in OpenCV using Python**

# %% [markdown]
# # Reading an image in OpenCV using Python

# %% [markdown]
# In this article, we’ll try to open an image by using OpenCV (Open Source Computer Vision). To use the OpenCV library in python, we need to install these libraries as a prerequisite:
#
# Numpy Library (Necessary, because OpenCV uses it in the background).
# OpenCV python

# %%
import cv2
import numpy
import matplotlib.pyplot as plt

# %%
# To read image from disk, we use
# cv2.imread function, in below method,
img = cv2.imread("Computer_vision.jpg", cv2.IMREAD_COLOR)
plt.title("Computer Vision")
plt.imshow(img)
plt.show()
