# %% [markdown]
# <a href="https://colab.research.google.com/github/sammymilitante/Modelsim/blob/master/Canny_Edge_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Canny Edge Detector**

# %% [markdown]
# # import the necessary packages

# %%
import argparse
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # Load the image, convert it to grayscale, and blur it slightly

# %%
image = cv2.imread("coins.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# %% [markdown]
# # show the original and blurred images

# %%
fig, ax = plt.subplots(1, 2, figsize=(16, 8))
fig.tight_layout()

ax[0].imshow(image)
ax[0].set_title("Original")

ax[1].imshow(blurred)
ax[1].set_title("Blurred")
# Out:
# Text(0.5, 1.0, 'Blurred')

# %%
image = cv2.imread("coins.png")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
blurred = cv2.GaussianBlur(gray, (5, 5), 0)


# Compute a "wide", "mid-range", and "tight" threshold for the edges using the Canny edge detector

wide = cv2.Canny(blurred, 10, 200)
mid = cv2.Canny(blurred, 30, 150)
tight = cv2.Canny(blurred, 240, 250)

fig, ax = plt.subplots(1, 3, figsize=(16, 8))
fig.tight_layout()

# show the output Canny edge maps

ax[0].imshow(wide)
ax[0].set_title("Wide Edge Map")

ax[1].imshow(mid)
ax[1].set_title("Mid Edge Map")

ax[2].imshow(tight)
ax[2].set_title("Tight Edge Map")
# Out:
# Text(0.5, 1.0, 'Tight Edge Map')
